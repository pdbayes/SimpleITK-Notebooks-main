# %% [markdown]
# # Welcome to SimpleITK Jupyter Notebooks
#
#
# ## Newcomers to Jupyter Notebooks:
# 1. We use two types of cells, code and markdown.
# 2. To run a code cell, select it (mouse or arrow key so that it is highlighted) and then press shift+enter which also moves focus to the next cell or ctrl+enter which doesn't.
# 3. Closing the browser window does not close the Jupyter server. To close the server, go to the terminal where you ran it and press ctrl+c twice.
#
# For additional details see the [Jupyter project documentation](https://jupyter.org/documentation) on Jupyter Notebook or JupyterLab.
#
# ## SimpleITK Environment Setup
#
# Check that SimpleITK and auxiliary program(s) are correctly installed in your environment, and that you have the SimpleITK version which you expect (<b>requires network connectivity</b>).
#
# You can optionally download all of the data used in the notebooks in advance. This step is only necessary if you expect to run the notebooks without network connectivity.

# %% [markdown]
# The following cell checks that all expected packages are installed.

# %%
import importlib
from distutils.version import LooseVersion

# check that all packages are installed (see requirements.txt file)
required_packages = {
    "jupyter",
    "numpy",
    "matplotlib",
    "ipywidgets",
    "scipy",
    "pandas",
    "numba",
    "multiprocess",
    "SimpleITK",
}

problem_packages = list()
# Iterate over the required packages: If the package is not installed
# ignore the exception.
for package in required_packages:
    try:
        p = importlib.import_module(package)
    except ImportError:
        problem_packages.append(package)

if len(problem_packages) == 0:
    print("All is well.")
else:
    print(
        "The following packages are required but not installed: "
        + ", ".join(problem_packages)
    )
# Out:
# All is well.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import SimpleITK as sitk

# %run update_path_to_download_script
from downloaddata import fetch_data, fetch_data_all

from ipywidgets import interact

print(sitk.Version())
# Out:
# SimpleITK Version: 2.5.2 (ITK 5.4)
# Compiled: Jun 13 2025 19:12:57

# %% [markdown]
# We expect that you have an external image viewer installed. The default viewer is <a href="https://fiji.sc/#download">Fiji</a>. If you have another viewer (i.e. ITK-SNAP or 3D Slicer) you will need to set an environment variable to point to it. This can be done from within a notebook as shown below.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: SimpleITK>2.2.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 1)) (2.5.2)
# Requirement already satisfied: jupyter in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: matplotlib in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 3)) (3.10.3)
# Requirement already satisfied: ipywidgets in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: ipympl in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 5)) (0.9.7)
# Requirement already satisfied: numpy in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 6)) (2.2.6)
# Requirement already satisfied: scipy in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 7)) (1.16.1)
# Requirement already satisfied: pandas in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 8)) (2.3.2)
# Requirement already satisfied: numba in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 9)) (0.61.2)
# Requirement already satisfied: multiprocess in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 10)) (0.70.18)
# Requirement already satisfied: tqdm in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: requests in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 12)) (2.32.5)
# Requirement already satisfied: notebook in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (7.4.5)
# Requirement already satisfied: jupyter-console in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (6.30.1)
# Requirement already satisfied: jupyterlab in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter->-r requirements.txt (line 2)) (4.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipywidgets->-r requirements.txt (line 4)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipywidgets->-r requirements.txt (line 4)) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipywidgets->-r requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->-r requirements.txt (line 4)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->-r requirements.txt (line 4)) (3.0.15)
# Requirement already satisfied: colorama in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\bayes\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from numba->-r requirements.txt (line 9)) (0.44.0)
# Requirement already satisfied: dill>=0.4.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from multiprocess->-r requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from requests->-r requirements.txt (line 12)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from requests->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from requests->-r requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from requests->-r requirements.txt (line 12)) (2025.4.26)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: six>=1.5 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (1.8.15)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (5.8.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (27.0.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (6.5.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 2)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 2)) (311)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->jupyter->-r requirements.txt (line 2)) (80.9.0)
# Requirement already satisfied: anyio in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (4.25.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 2)) (4.14.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\bayes\appdata\local\programs\python\python313\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 2)) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\bayes\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\bayes\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 4)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Uncomment the line below to change the default external viewer to your viewer of choice and test that it works.
#%env SITK_SHOW_COMMAND "C:\Users\bayes\Fiji.app\fiji-windows-x64.exe"

# Retrieve an image from the network, read it and display using the external viewer.
# The show method will also set the display window's title and by setting debugOn to True,
# will also print information with respect to the command it is attempting to invoke.
# NOTE: The debug information is printed to the terminal from which you launched the notebook
#       server.
import os
os.environ["SITK_SHOW_COMMAND"] = r"C:\Users\bayes\Fiji.app\fiji-windows-x64.exe"
sitk.Show(sitk.ReadImage(fetch_data("SimpleITK.jpg")), "SimpleITK Logo", debugOn=True)
# Out:
# Fetching SimpleITK.jpg

# %% [markdown]
# Now we check that the ipywidgets will display correctly. When you run the following cell you should see a slider.
#
# If you don't see a slider please shutdown the Jupyter server, at the command line prompt press Control-c twice, and then run the following command (jupyter notebook 5.2 or earlier):
#
# ```jupyter nbextension enable --py --sys-prefix widgetsnbextension```

# %%
interact(lambda x: x, x=(0, 10));
# Out:
# interactive(children=(IntSlider(value=5, description='x', max=10), Output()), _dom_classes=('widget-interact',…

# %% [markdown]
# Download all of the data in advance if you expect to be working offline (may take a couple of minutes).

# %%
fetch_data_all(os.path.join("..", "Data"), os.path.join("..", "Data", "manifest.json"))
